# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with Arnitha.txt','r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 28/06/2023, 11:26 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 04/07/2023, 08:08 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 07/09/2023, 18:53 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 25/09/2023, 18:30 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 17/01/2024, 11:22 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 25/01/2024, 01:42 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 28/09/2024, 13:18 - Madhavan: Heyy
# 28/09/2024, 13:18 - Madhavan: Madhavan here
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern,data)[1:]
len(messages)
# Out:
# 8848

# %%
dates = re.findall(pattern,data)
dates
# Out:
# ['28/06/2023, 11:26 - ',
#  '04/07/2023, 08:08 - ',
#  '07/09/2023, 18:53 - ',
#  '25/09/2023, 18:30 - ',
#  '17/01/2024, 11:22 - ',
#  '25/01/2024, 01:42 - ',
#  '28/09/2024, 13:18 - ',
#  '28/09/2024, 13:18 - ',
#  '28/09/2024, 13:19 - ',
#  '28/09/2024, 13:19 - ',
#  '28/09/2024, 13:19 - ',
#  '28/09/2024, 13:19 - ',
#  '28/09/2024, 13:20 - ',
#  '28/09/2024, 13:20 - ',
#  '28/09/2024, 13:21 - ',
#  '28/09/2024, 13:21 - ',
#  '28/09/2024, 13:22 - ',
#  '28/09/2024, 13:23 - ',
#  '28/09/2024, 13:23 - ',
#  '28/09/2024, 13:23 - ',
#  '28/09/2024, 13:23 - ',
#  '28/09/2024, 13:24 - ',
#  '28/09/2024, 16:45 - ',
#  '28/09/2024, 16:45 - ',
#  '02/03/2025, 11:40 - ',
#  '02/03/2025, 11:40 - ',
#  '02/03/2025, 11:40 - ',
#  '02/03/2025, 11:40 - ',
#  '02/03/2025, 11:40 - ',
#  '02/03/2025, 11:42 - ',
#  '02/03/2025, 11:42 - ',
#  '02/03/2025, 11:43 - ',
#  '02/03/2025, 11:43 - ',
#  '02/03/2025, 11:44 - ',
#  '02/03/2025, 11:46 - ',
#  '02/03/2025, 11:46 - ',
#  '02/03/2025, 11:46 - ',
# ...

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})
df['message_date'] = df['message_date'].str.split(' - ').str[0].str.strip()
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %H:%M')
df.rename(columns={'message_date': 'date'}, inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. O... 2023-06-28 11:26:00
# 1  Messages and calls are end-to-end encrypted. O... 2023-07-04 08:08:00
# 2  Messages and calls are end-to-end encrypted. O... 2023-09-07 18:53:00
# 3  Messages and calls are end-to-end encrypted. O... 2023-09-25 18:30:00
# 4  Messages and calls are end-to-end encrypted. O... 2024-01-17 11:22:00

# %%
df.shape
# Out:
# (8848, 2)

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

df.head
# Out:
# <bound method NDFrame.head of                     date                user  \
# 0    2023-06-28 11:26:00  group_notification
# 1    2023-07-04 08:08:00  group_notification
# 2    2023-09-07 18:53:00  group_notification
# 3    2023-09-25 18:30:00  group_notification
# 4    2024-01-17 11:22:00  group_notification
# ...                  ...                 ...
# 8843 2025-11-26 03:38:00            Madhavan
# 8844 2025-11-26 03:39:00            Madhavan
# 8845 2025-11-26 03:39:00            Madhavan
# 8846 2025-11-26 16:34:00            Madhavan
# 8847 2025-11-26 16:35:00            Madhavan
#
#                                                 message
# 0     Messages and calls are end-to-end encrypted. O...
# 1     Messages and calls are end-to-end encrypted. O...
# 2     Messages and calls are end-to-end encrypted. O...
# 3     Messages and calls are end-to-end encrypted. O...
# 4     Messages and calls are end-to-end encrypted. O...
# ...

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-28 11:26:00  group_notification
# 1 2023-07-04 08:08:00  group_notification
# 2 2023-09-07 18:53:00  group_notification
# 3 2023-09-25 18:30:00  group_notification
# 4 2024-01-17 11:22:00  group_notification
#
#                                              message  year
# 0  Messages and calls are end-to-end encrypted. O...  2023
# 1  Messages and calls are end-to-end encrypted. O...  2023
# 2  Messages and calls are end-to-end encrypted. O...  2023
# 3  Messages and calls are end-to-end encrypted. O...  2023
# 4  Messages and calls are end-to-end encrypted. O...  2024

# %%
df['month'] = df['date'].dt.month_name()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-28 11:26:00  group_notification
# 1 2023-07-04 08:08:00  group_notification
# 2 2023-09-07 18:53:00  group_notification
# 3 2023-09-25 18:30:00  group_notification
# 4 2024-01-17 11:22:00  group_notification
#
#                                              message  year      month
# 0  Messages and calls are end-to-end encrypted. O...  2023       June
# 1  Messages and calls are end-to-end encrypted. O...  2023       July
# 2  Messages and calls are end-to-end encrypted. O...  2023  September
# 3  Messages and calls are end-to-end encrypted. O...  2023  September
# 4  Messages and calls are end-to-end encrypted. O...  2024    January

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-28 11:26:00  group_notification
# 1 2023-07-04 08:08:00  group_notification
# 2 2023-09-07 18:53:00  group_notification
# 3 2023-09-25 18:30:00  group_notification
# 4 2024-01-17 11:22:00  group_notification
#
#                                              message  year      month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2023       June   28
# 1  Messages and calls are end-to-end encrypted. O...  2023       July    4
# 2  Messages and calls are end-to-end encrypted. O...  2023  September    7
# 3  Messages and calls are end-to-end encrypted. O...  2023  September   25
# 4  Messages and calls are end-to-end encrypted. O...  2024    January   17
#
#    hour  minute
# 0    11      26
# 1     8       8
# 2    18      53
# 3    18      30
# 4    11      22

# %%
df[df['user'] == 'Arnitha'].shape
# Out:
# (5126, 8)

# %%
words=[]
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 71048

# %%
# !pip install urlextract
# Out:
# ...
#   Obtaining dependency information for urlextract from https://files.pythonhosted.org/packages/cb/cb/82ef2994dec66351aaffa45061f30051b6b557bf592952f14657f38b6e43/urlextract-1.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for uritools from https://files.pythonhosted.org/packages/8c/74/0987d204b5fbf83861affa6b36a20da22cb3fe708583b955c99ab834bd5a/uritools-5.0.0-py3-none-any.whl.metadata
# ...

# %%
from urlextract import URLExtract

extractor = URLExtract()   # <-- YOU FORGOT THIS

links = []

for message in df['message']:
    urls = extractor.find_urls(message)
    links.extend(urls)

# %%
len(links)
# Out:
# 22
